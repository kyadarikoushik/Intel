# %%
#This command will intall the custom trained file
# !git clone https://github.com/koushikkyadari07742/custom_train_dataset.git
# Out:
# Cloning into 'custom_train_dataset'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 81 (delta 0), reused 0 (delta 0), pack-reused 78
# Unpacking objects: 100% (81/81), 174.65 KiB | 5.63 MiB/s, done.

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/78.2 GB disk)

# %%
#This command help to move the file "custom_data.yaml" to the "data" which is in yolov5
# !mv /content/custom_train_dataset/custom_data.yaml /content/yolov5/data

# %%
# !python detect.py --weights runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source /content/trail25.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=/content/trail25.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 261, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 256, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/detect.py", line 98, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/content/yolov5/models/common.py", line 344, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#   File "/content/yolov5/models/experimental.py", line 79, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train/exp3/weights/last.pt'

# %%
# Train YOLOv5s for creating datasets $$this doesn't train the data but create the datasets folder which is essential for next step
# !python train.py --img 640 --batch 16 --epochs 3 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET INFO: Using '/content/yolov5/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
#
# Dataset not found ⚠️, missing paths ['/content/datasets/coco128/train_data/images/val']
# Downloading https://ultralytics.com/assets/coco128.zip to coco128.zip...
# 100%|██████████| 6.66M/6.66M [00:00<00:00, 165MB/s]
# Dataset download success ✅ (0.5s), saved to /content/datasets
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 20.4MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# Traceback (most recent call last):
#   File "/content/yolov5/utils/dataloaders.py", line 478, in __init__
#     raise FileNotFoundError(f'{prefix}{p} does not exist')
# FileNotFoundError: train: /content/datasets/coco128/train_data/images/train does not exist
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 647, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 536, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/yolov5/train.py", line 195, in train
#     train_loader, dataset = create_dataloader(train_path,
#   File "/content/yolov5/utils/dataloaders.py", line 124, in create_dataloader
#     dataset = LoadImagesAndLabels(
#   File "/content/yolov5/utils/dataloaders.py", line 483, in __init__
#     raise Exception(f'{prefix}Error loading data from {path}: {e}\n{HELP_URL}') from e
# Exception: train: Error loading data from /content/datasets/coco128/train_data/images/train: train: /content/datasets/coco128/train_data/images/train does not exist
# See https://docs.ultralytics.com/yolov5/tutorials/train_custom_data
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Others:
# COMET INFO:     Created from                : YOLOv5
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : 1
# COMET INFO:     evolve              : 1
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     save_dir            : runs/train/exp
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 3 (1.79 KB)
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /content/yolov5/.cometml-runs/a62df279840c42369b47b80706113685.zip

# %%
#This command help to move the file "train_data" to the "coco128" which is in datasets
# !mv /content/custom_train_dataset/train_data /content/datasets/coco128

# %%
# Train YOLOv5s on COCO128 for 50 epochs
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET INFO: Using '/content/yolov5/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/coco128/train_data/labels/train... 29 images, 0 backgrounds, 0 corrupt: 100%|██████████| 29/29 [00:00<00:00, 643.83it/s]
# train: New cache created: /content/datasets/coco128/train_data/labels/train.cache
# train: Caching images (0.0GB ram): 100%|██████████| 29/29 [00:00<00:00, 409.04it/s]
# val: Scanning /content/datasets/coco128/train_data/labels/val... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<00:00, 256.72it/s]
# val: New cache created: /content/datasets/coco128/train_data/labels/val.cache
# val: Caching images (0.0GB ram): 100%|██████████| 10/10 [00:00<00:00, 183.36it/s]
#
# AutoAnchor: 2.59 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99      3.46G    0.07872    0.03338          0         30        640: 100%|██████████| 2/2 [00:04<00:00,  2.23s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
#                    all         10         10      0.002        0.6    0.00811    0.00199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      3.46G     0.1033    0.03292          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  2.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.000s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
#                    all         10         10    0.00111        0.2    0.00208   0.000356
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      3.46G    0.07898    0.03242          0         28        640: 100%|██████████| 2/2 [00:00<00:00,  3.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 1.000s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
#                    all         10         10      0.002        0.6    0.00516     0.0016
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      3.46G    0.07674    0.03366          0         42        640: 100%|██████████| 2/2 [00:00<00:00,  5.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]
#                    all         10         10    0.00233        0.7    0.00441    0.00101
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      3.46G    0.09401     0.0334          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  5.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
#                    all         10         10    0.00233        0.7    0.00469    0.00097
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      3.46G    0.07101    0.03315          0         40        640: 100%|██████████| 2/2 [00:00<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]
#                    all         10         10    0.00267        0.8      0.008     0.0012
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      3.46G    0.07655    0.03561          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  4.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
#                    all         10         10    0.00333          1     0.0201     0.0038
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      3.46G    0.05963    0.03408          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  4.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.44it/s]
#                    all         10         10    0.00333          1     0.0315    0.00687
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      3.46G    0.06238    0.03063          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.73it/s]
#                    all         10         10    0.00333          1     0.0252    0.00742
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      3.46G    0.08223    0.03146          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
#                    all         10         10     0.0347        0.4      0.066     0.0162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      3.46G    0.05905    0.03381          0         42        640: 100%|██████████| 2/2 [00:00<00:00,  5.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
#                    all         10         10     0.0137        0.9     0.0931      0.033
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      3.46G    0.05891    0.02978          0         29        640: 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
#                    all         10         10     0.0516        0.9      0.219     0.0549
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      3.46G    0.08532    0.03004          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  4.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.20it/s]
#                    all         10         10    0.00333          1     0.0701     0.0169
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      3.46G    0.05659    0.03188          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  5.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.05it/s]
#                    all         10         10    0.00942          1      0.103     0.0296
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      3.46G    0.05199    0.03135          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  5.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.57it/s]
#                    all         10         10     0.0551        0.9      0.133     0.0354
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      3.46G    0.05029    0.02731          0         32        640: 100%|██████████| 2/2 [00:00<00:00,  5.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
#                    all         10         10    0.00913          1      0.187     0.0568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      3.46G    0.04669    0.03024          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  5.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.61it/s]
#                    all         10         10     0.0184          1      0.158     0.0488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/99      3.46G    0.04802    0.03129          0         40        640: 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.07it/s]
#                    all         10         10     0.0671          1      0.185     0.0685
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/99      3.46G    0.04644    0.03121          0         37        640: 100%|██████████| 2/2 [00:00<00:00,  4.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.01it/s]
#                    all         10         10      0.159        0.9      0.214     0.0789
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/99      3.46G    0.07255    0.02874          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
#                    all         10         10      0.191        0.3      0.281      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/99      3.46G    0.04743    0.02767          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  5.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
#                    all         10         10      0.497        0.5      0.467      0.253
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/99      3.46G    0.04425    0.02884          0         41        640: 100%|██████████| 2/2 [00:00<00:00,  5.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.59it/s]
#                    all         10         10      0.447        0.3      0.459      0.224
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/99      3.46G    0.07042    0.02613          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.37it/s]
#                    all         10         10          1       0.28      0.451      0.232
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/99      3.46G    0.04447    0.02523          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  4.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.72it/s]
#                    all         10         10      0.271        0.4      0.427      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/99      3.46G    0.04354    0.02444          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  4.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
#                    all         10         10      0.438        0.3      0.478      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/99      3.46G     0.0423    0.02292          0         35        640: 100%|██████████| 2/2 [00:00<00:00,  5.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.91it/s]
#                    all         10         10      0.534        0.5      0.603      0.289
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/99      3.46G    0.04332    0.02395          0         35        640: 100%|██████████| 2/2 [00:00<00:00,  5.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.12it/s]
#                    all         10         10      0.433        0.5      0.411      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/99      3.46G     0.0597    0.02332          0         35        640: 100%|██████████| 2/2 [00:00<00:00,  5.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.92it/s]
#                    all         10         10      0.433        0.5      0.411      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/99      3.46G     0.0394    0.02656          0         39        640: 100%|██████████| 2/2 [00:00<00:00,  5.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.84it/s]
#                    all         10         10      0.772        0.8      0.762      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/99      3.46G    0.03793    0.02307          0         28        640: 100%|██████████| 2/2 [00:00<00:00,  5.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.11it/s]
#                    all         10         10      0.223        0.6      0.233     0.0842
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/99      3.46G    0.06948    0.02348          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  5.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.38it/s]
#                    all         10         10      0.223        0.6      0.233     0.0842
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/99      3.46G    0.04091    0.02324          0         39        640: 100%|██████████| 2/2 [00:00<00:00,  5.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.83it/s]
#                    all         10         10      0.485        0.9      0.567      0.254
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/99      3.46G    0.06051    0.02092          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  5.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.71it/s]
#                    all         10         10      0.382          1      0.651      0.385
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/99      3.46G     0.0381    0.02219          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  6.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.67it/s]
#                    all         10         10      0.382          1      0.651      0.385
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/99      3.46G    0.06004       0.02          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  5.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.31it/s]
#                    all         10         10      0.271        0.9      0.349      0.152
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/99      3.46G    0.04199    0.02144          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  4.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
#                    all         10         10      0.454        0.9      0.632       0.29
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/99      3.46G    0.04152    0.01933          0         29        640: 100%|██████████| 2/2 [00:00<00:00,  5.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.77it/s]
#                    all         10         10      0.454        0.9      0.632       0.29
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/99      3.46G    0.03992    0.01911          0         28        640: 100%|██████████| 2/2 [00:00<00:00,  4.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.71it/s]
#                    all         10         10      0.527        0.6       0.56      0.279
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/99      3.46G     0.0353    0.02093          0         35        640: 100%|██████████| 2/2 [00:00<00:00,  4.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.90it/s]
#                    all         10         10      0.301          1      0.342       0.13
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/99      3.46G    0.04712    0.01719          0         27        640: 100%|██████████| 2/2 [00:00<00:00,  6.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.73it/s]
#                    all         10         10      0.301          1      0.342       0.13
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/99      3.46G    0.06728    0.01962          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  5.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.76it/s]
#                    all         10         10      0.534          1      0.656      0.301
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/99      3.46G    0.03869    0.01811          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.87it/s]
#                    all         10         10      0.654        0.9      0.675      0.303
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/99      3.46G     0.0389    0.02078          0         42        640: 100%|██████████| 2/2 [00:00<00:00,  6.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.79it/s]
#                    all         10         10      0.654        0.9      0.675      0.303
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/99      3.46G    0.03752    0.01939          0         32        640: 100%|██████████| 2/2 [00:00<00:00,  5.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.79it/s]
#                    all         10         10      0.544      0.955      0.653      0.348
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/99      3.46G    0.05993     0.0178          0         30        640: 100%|██████████| 2/2 [00:00<00:00,  5.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.00it/s]
#                    all         10         10      0.544      0.955      0.653      0.348
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/99      3.46G    0.04085    0.01801          0         30        640: 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  8.23it/s]
#                    all         10         10      0.523        0.9       0.63      0.297
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/99      3.46G    0.05483    0.01974          0         30        640: 100%|██████████| 2/2 [00:00<00:00,  6.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.12it/s]
#                    all         10         10      0.523        0.9       0.63      0.297
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/99      3.46G     0.0373    0.01836          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  4.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.38it/s]
#                    all         10         10       0.62          1      0.845       0.57
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/99      3.46G    0.03365    0.02006          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  6.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.32it/s]
#                    all         10         10       0.62          1      0.845       0.57
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/99      3.46G    0.03286     0.0232          0         40        640: 100%|██████████| 2/2 [00:00<00:00,  3.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.98it/s]
#                    all         10         10      0.583      0.978      0.825      0.414
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/99      3.46G    0.04199     0.0152          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  4.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s]
#                    all         10         10      0.583      0.978      0.825      0.414
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/99      3.46G    0.03865    0.01856          0         29        640: 100%|██████████| 2/2 [00:00<00:00,  4.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
#                    all         10         10      0.901          1      0.959      0.478
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/99      3.46G    0.03119    0.01988          0         37        640: 100%|██████████| 2/2 [00:00<00:00,  6.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.86it/s]
#                    all         10         10      0.901          1      0.959      0.478
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/99      3.46G    0.03417    0.01884          0         35        640: 100%|██████████| 2/2 [00:00<00:00,  5.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.36it/s]
#                    all         10         10      0.764      0.974      0.903      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/99      3.46G    0.03212    0.01807          0         35        640: 100%|██████████| 2/2 [00:00<00:00,  5.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.40it/s]
#                    all         10         10      0.764      0.974      0.903      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/99      3.46G    0.05609    0.01696          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  5.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.78it/s]
#                    all         10         10      0.802        0.9      0.844      0.442
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/99      3.46G      0.033    0.01751          0         37        640: 100%|██████████| 2/2 [00:00<00:00,  5.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.88it/s]
#                    all         10         10      0.802        0.9      0.844      0.442
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/99      3.46G    0.03157    0.01777          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  5.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.57it/s]
#                    all         10         10      0.584          1      0.804      0.545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/99      3.46G    0.03354    0.01528          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  6.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.96it/s]
#                    all         10         10      0.584          1      0.804      0.545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/99      3.46G    0.03556     0.0155          0         29        640: 100%|██████████| 2/2 [00:00<00:00,  5.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.16it/s]
#                    all         10         10       0.76          1      0.954      0.574
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       60/99      3.46G      0.031    0.01581          0         32        640: 100%|██████████| 2/2 [00:00<00:00,  5.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.09it/s]
#                    all         10         10       0.76          1      0.954      0.574
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       61/99      3.46G    0.02857    0.01776          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  5.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.05it/s]
#                    all         10         10      0.888          1      0.977      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       62/99      3.46G    0.03112    0.01637          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  5.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
#                    all         10         10      0.888          1      0.977      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       63/99      3.46G    0.02858    0.01823          0         37        640: 100%|██████████| 2/2 [00:00<00:00,  4.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
#                    all         10         10      0.704          1       0.93        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       64/99      3.46G    0.02793    0.01609          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
#                    all         10         10      0.704          1       0.93        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       65/99      3.46G    0.03037    0.01644          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  4.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.98it/s]
#                    all         10         10      0.907      0.982      0.968      0.593
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       66/99      3.46G    0.02616    0.01639          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  5.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.98it/s]
#                    all         10         10      0.907      0.982      0.968      0.593
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       67/99      3.46G    0.02758    0.01639          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  5.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.44it/s]
#                    all         10         10      0.749        0.9       0.93      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       68/99      3.46G    0.03058    0.01459          0         29        640: 100%|██████████| 2/2 [00:00<00:00,  5.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.18it/s]
#                    all         10         10      0.749        0.9       0.93      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       69/99      3.46G     0.0294    0.01417          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  5.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.06it/s]
#                    all         10         10      0.821          1      0.968       0.52
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       70/99      3.46G    0.02846    0.01663          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  5.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.98it/s]
#                    all         10         10      0.821          1      0.968       0.52
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       71/99      3.46G    0.07135    0.01663          0         37        640: 100%|██████████| 2/2 [00:00<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.28it/s]
#                    all         10         10      0.899          1      0.986      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       72/99      3.46G    0.03698    0.01568          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  6.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.03it/s]
#                    all         10         10      0.899          1      0.986      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       73/99      3.46G    0.04255    0.01639          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  5.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.90it/s]
#                    all         10         10      0.899          1      0.986      0.589
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       74/99      3.46G    0.02628     0.0144          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  6.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.26it/s]
#                    all         10         10      0.899          1      0.986      0.589
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       75/99      3.46G    0.02789    0.01562          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  5.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.96it/s]
#                    all         10         10      0.901          1      0.995      0.602
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       76/99      3.46G    0.03653    0.01358          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  6.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.20it/s]
#                    all         10         10      0.901          1      0.995      0.602
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       77/99      3.46G    0.02514    0.01709          0         43        640: 100%|██████████| 2/2 [00:00<00:00,  4.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.85it/s]
#                    all         10         10      0.899          1      0.986       0.64
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       78/99      3.46G    0.02416    0.01339          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  4.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  2.77it/s]
#                    all         10         10      0.899          1      0.986       0.64
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       79/99      3.46G      0.034    0.01351          0         32        640: 100%|██████████| 2/2 [00:00<00:00,  4.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  8.26it/s]
#                    all         10         10      0.899          1      0.986       0.59
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       80/99      3.46G    0.02836    0.01484          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  5.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.80it/s]
#                    all         10         10      0.899          1      0.986       0.59
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       81/99      3.46G    0.02254    0.01249          0         25        640: 100%|██████████| 2/2 [00:00<00:00,  5.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.51it/s]
#                    all         10         10      0.997          1      0.995      0.572
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       82/99      3.46G    0.03128    0.01564          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  5.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.31it/s]
#                    all         10         10      0.997          1      0.995      0.572
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       83/99      3.46G    0.02348    0.01597          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  4.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  8.85it/s]
#                    all         10         10      0.996          1      0.995      0.655
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       84/99      3.46G    0.02153    0.01391          0         32        640: 100%|██████████| 2/2 [00:00<00:00,  5.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.47it/s]
#                    all         10         10      0.996          1      0.995      0.655
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       85/99      3.46G    0.02216    0.01378          0         30        640: 100%|██████████| 2/2 [00:00<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.70it/s]
#                    all         10         10      0.992          1      0.995      0.584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       86/99      3.46G    0.02843    0.01502          0         35        640: 100%|██████████| 2/2 [00:00<00:00,  5.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.16it/s]
#                    all         10         10      0.992          1      0.995      0.584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       87/99      3.46G    0.02107    0.01444          0         37        640: 100%|██████████| 2/2 [00:00<00:00,  5.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.89it/s]
#                    all         10         10      0.991          1      0.995      0.636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      3.46G    0.02163    0.01457          0         36        640: 100%|██████████| 2/2 [00:00<00:00,  5.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.49it/s]
#                    all         10         10      0.991          1      0.995      0.636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      3.46G    0.02209    0.01428          0         30        640: 100%|██████████| 2/2 [00:00<00:00,  4.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  8.41it/s]
#                    all         10         10      0.989          1      0.995      0.573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      3.46G    0.02277    0.01495          0         37        640: 100%|██████████| 2/2 [00:00<00:00,  5.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
#                    all         10         10      0.989          1      0.995      0.573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      3.46G    0.02079     0.0155          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  4.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
#                    all         10         10       0.99          1      0.995      0.626
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      3.46G    0.01889    0.01402          0         29        640: 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
#                    all         10         10       0.99          1      0.995      0.626
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      3.46G    0.02058    0.01397          0         33        640: 100%|██████████| 2/2 [00:00<00:00,  3.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
#                    all         10         10       0.99          1      0.995      0.616
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      3.46G    0.02408    0.01298          0         31        640: 100%|██████████| 2/2 [00:00<00:00,  5.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.97it/s]
#                    all         10         10       0.99          1      0.995      0.616
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      3.46G    0.02151    0.01254          0         25        640: 100%|██████████| 2/2 [00:00<00:00,  4.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.37it/s]
#                    all         10         10       0.99          1      0.995      0.593
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      3.46G    0.02982    0.01447          0         32        640: 100%|██████████| 2/2 [00:00<00:00,  6.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  5.00it/s]
#                    all         10         10       0.99          1      0.995      0.593
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      3.46G    0.02101    0.01581          0         38        640: 100%|██████████| 2/2 [00:00<00:00,  5.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.74it/s]
#                    all         10         10       0.99          1      0.995      0.609
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      3.46G    0.02156    0.01544          0         42        640: 100%|██████████| 2/2 [00:00<00:00,  4.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.35it/s]
#                    all         10         10       0.99          1      0.995      0.609
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      3.46G    0.03298    0.01422          0         34        640: 100%|██████████| 2/2 [00:00<00:00,  4.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  6.82it/s]
#                    all         10         10       0.99          1      0.995      0.616
#
# 100 epochs completed in 0.032 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 14.4MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  7.72it/s]
#                    all         10         10      0.996          1      0.995      0.655
# Results saved to runs/train/exp3
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [10]                  : (0.5668646097183228, 1.8217642307281494)
# COMET INFO:     metrics/mAP_0.5 [200]      : (0.0020817991631799167, 0.995)
# COMET INFO:     metrics/mAP_0.5:0.95 [200] : (0.00035632507760831425, 0.6553704777592001)
# COMET INFO:     metrics/precision [200]    : (0.0011111111111111111, 1.0)
# COMET INFO:     metrics/recall [200]       : (0.2, 1.0)
# COMET INFO:     train/box_loss [200]       : (0.018892154097557068, 0.1033327504992485)
# COMET INFO:     train/cls_loss             : 0.0
# COMET INFO:     train/obj_loss [200]       : (0.012493735179305077, 0.03560534864664078)
# COMET INFO:     val/box_loss [200]         : (0.016613097861409187, 0.08378596603870392)
# COMET INFO:     val/cls_loss               : 0.0
# COMET INFO:     val/obj_loss [200]         : (0.0033626556396484375, 0.02123260498046875)
# COMET INFO:     x/lr0 [200]                : (0.0002980000000000002, 0.09910000000000001)
# COMET INFO:     x/lr1 [200]                : (0.0001, 0.0050975099999999995)
# COMET INFO:     x/lr2 [200]                : (0.0001, 0.0050975099999999995)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.006250000000000001
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : 1
# COMET INFO:     evolve              : 1
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     save_dir            : runs/train/exp3
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (1.02 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 6
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /content/yolov5/.cometml-runs/b81aae3214fb47e187ac3c9ba6ce0ad0.zip

# %%
#After running the training successfully the result is saves in this path for ex "runs/train/exp2/weights/best.pt..."

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/Yamaha.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp3/weights
)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0018.jpg (deflated 2%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0005.jpg (deflated 0%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0015.jpg (deflated 7%)
#   adding: content/datasets/coco128/train_data/images/train/download (4).jpg (deflated 7%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0008.jpg (deflated 2%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0006.jpg (deflated 7%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0012.jpg (deflated 7%)
#   adding: content/datasets/coco128/train_data/images/train/download.jpg (deflated 9%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0020.jpg (deflated 0%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0007.jpg (deflated 7%)
#   adding: content/datasets/coco128/train_data/images/train/images (2).jpg (deflated 4%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0017.jpg (deflated 10%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0004.jpg (deflated 2%)
#   adding: content/datasets/coco128/train_data/images/train/images.jpg (deflated 0%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0014.jpg (deflated 0%)
#   adding: content/datasets/coco128/train_data/images/train/IMG-20230621-WA0016.jpg (deflated 16%)
#   adding: content/datasets/coco128/train_data/images/train/images (1).jpg (deflated 5%)
#   adding: content/datasets/coco128/train_data/labels/ (stored 0%)
#   adding: content/datasets/coco128/train_data/labels/train.cache (deflated 65%)
#   adding: content/datasets/coco128/train_data/labels/val/ (stored 0%)
#   adding: content/datasets/coco128/train_data/labels/val/IMG-20230621-WA0003.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/val/IMG-20230621-WA0018.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/val/IMG-20230621-WA0005.txt (deflated 14%)
#   adding: content/datasets/coco128/train_data/labels/val/IMG-20230621-WA0016.txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/val/images (1).txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/val/IMG-20230621-WA0012.txt (deflated 5%)
#   adding: content/datasets/coco128/train_data/labels/val/IMG-20230621-WA0004.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/val/IMG-20230621-WA0010.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/val/download (4).txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/val/download (1).txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/train/ (stored 0%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0006.txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0017.txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/train/download (2).txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0003.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0018.txt (deflated 30%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0019.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0005.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0009.txt (deflated 16%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0020.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0016.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0011.txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/train/download (3).txt (deflated 5%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0015.txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0013.txt (deflated 5%)
#   adding: content/datasets/coco128/train_data/labels/train/download (6).txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0007.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/images (1).txt (deflated 14%)
#   adding: content/datasets/coco128/train_data/labels/train/download (5).txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0012.txt (deflated 14%)
#   adding: content/datasets/coco128/train_data/labels/train/images.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0004.txt (deflated 16%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0010.txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/train/images (3).txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/images (2).txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/download (4).txt (deflated 5%)
#   adding: content/datasets/coco128/train_data/labels/train/download (1).txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0014.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/train/download.txt (deflated 11%)
#   adding: content/datasets/coco128/train_data/labels/train/IMG-20230621-WA0008.txt (deflated 8%)
#   adding: content/datasets/coco128/train_data/labels/val.cache (deflated 54%)
#   adding: content/datasets/coco128/README.txt (deflated 40%)
#   adding: content/datasets/coco128/labels/ (stored 0%)
#   adding: content/datasets/coco128/labels/train2017/ (stored 0%)
#   adding: content/datasets/coco128/labels/train2017/000000000042.txt (deflated 9%)
#   adding: content/datasets/coco128/labels/train2017/000000000110.txt (deflated 57%)
#   adding: content/datasets/coco128/labels/train2017/000000000589.txt (deflated 27%)
#   adding: content/datasets/coco128/labels/train2017/000000000514.txt (deflated 8%)
#   adding: content/datasets/coco128/labels/train2017/000000000491.txt (deflated 45%)
#   adding: content/datasets/coco128/labels/train2017/000000000370.txt (deflated 26%)
#   adding: content/datasets/coco128/labels/train2017/000000000599.txt (deflated 47%)
#   adding: content/datasets/coco128/labels/train2017/000000000459.txt (deflated 29%)
#   adding: content/datasets/coco128/labels/train2017/000000000263.txt (deflated 28%)
#   adding: content/datasets/coco128/labels/train2017/000000000544.txt (deflated 55%)
#   adding: content/datasets/coco128/labels/train2017/000000000575.txt (deflated 5%)
#   adding: content/datasets/coco128/labels/train2017/000000000143.txt (deflated 53%)
#   adding: content/datasets/coco128/labels/train2017/000000000164.txt (deflated 60%)
#   adding: content/datasets/coco128/labels/train2017/000000000357.txt (deflated 56%)
#   adding: content/datasets/coco128/labels/train2017/000000000620.txt (deflated 28%)
#   adding: content/datasets/coco128/labels/train2017/000000000629.txt (deflated 8%)
#   adding: content/datasets/coco128/labels/train2017/000000000113.txt (deflated 56%)
#   adding: content/datasets/coco128/labels/train2017/000000000144.txt (deflated 39%)
#   adding: content/datasets/coco128/labels/train2017/000000000605.txt (deflated 41%)
#   adding: content/datasets/coco128/labels/train2017/000000000584.txt (deflated 55%)
#   adding: content/datasets/coco128/labels/train2017/000000